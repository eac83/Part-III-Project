# %%
import numpy as np
import h5py
import pandas as pd
from matplotlib import pyplot as plt
from pathlib import Path
import functions as fn
import box
import halo

# %%
plt.style.use(str(fn.HERE_PATH/'plot.mplstyle'))

# %%
redshifts = [3, 2, 1, 0]
x_bins = np.logspace(-2, 0, 21)
is_normalize = False
is_verbose = True

# %%
x = np.sqrt(x_bins[:-1]*x_bins[1:])

# %%
for z in redshifts:
    if is_verbose:
        print('--------------')
        print(f'z = {z}')
    boxes = np.array([])
    halos = np.array([])
    for model in fn.MODELS:
        model_path = fn.MODELS_PATH/model
        boxes = np.append(boxes, box.Box(model_path, fn.ZHOT[z]))
        fof_path = model_path/f'fof_subhalo_tab_{fn.ZHOT[z]}.hdf5'
        with h5py.File(fof_path) as fof:
            halo_masses = np.array(fof.get('Group/GroupMass'))
            ndx = np.array(np.where(halo_masses == np.amax(halo_masses)))[0]
            halo_pos = np.array(fof.get('Group/GroupPos'))[ndx]
            halo_r200c = np.array(fof.get('Group/Group_R_Crit200'))[ndx]
            
        halos = np.append(halos, halo.Halo(halo_pos, halo_r200c))
        
    if is_verbose:
        print('Calculating density profiles')

    [halo_i.get_density(boxes[i], x_bins) for i, halo_i in enumerate(halos)]

    with open(fn.HERE_PATH/'Mod_Density_Profiles'/f'gas_z{z}.csv', 'w') as f:
        header = 'model,'
        for i in range(x.shape[0]):
            header += f'rho_{i},'
        header = header[:-1] + '\n'
        f.write(header)
        for i, model in enumerate(fn.MODELS):
            np.savetxt(f, np.hstack(([i], halos[i].density_gas))[:,np.newaxis].T, delimiter=',')
# Out:
# --------------
# z = 3
# Calculating density profiles
# --------------
# z = 2
# Calculating density profiles
# --------------
# z = 1
# Calculating density profiles
# --------------
# z = 0
# Calculating density profiles

# %%
for z in redshifts:
    df = pd.read_csv(fn.HERE_PATH/'Mod_Density_Profiles'/f'gas_z{z}.csv')
    density = np.array(df.iloc[:,1:])
    halos = np.array([])

    for i in range(len(fn.MODELS)):
        halos = np.append(halos, halo.Halo(np.array([0, 0, 0]), 0))
        halos[-1].density_gas = density[i, :]

    if is_normalize:
        for i, halo_i in halos:
            if fn.MODELS[i] == 'REF':
                mass_ref = halo_i.mass
            halo_i.density *= mass_ref / halo_i.mass
    
    fg, ax = plt.subplots(2, figsize=(6,6), gridspec_kw={'height_ratios':[3,2]})
    fg.subplots_adjust(hspace=0)
    ax[0].loglog()
    ax[1].loglog()
    ax[0].set_xticklabels([])
    ax[1].set_xlabel(r'$r/r_{200}$')
    ax[0].set_ylabel(r'$\rho_\mathrm{gas} [h^{-1} \, \mathrm{M}_\odot (h^{-1}\,\mathrm{Mpc})^{-3}]$')
    ax[1].set_ylabel(r'$\rho_\mathrm{gas}/\rho_\mathrm{ref, gas}$')
    if is_normalize:
        ax[0].set_title(f'Normalized, $z={z}$')
    else:
        ax[0].set_title(f'$z={z}$')
        
    for i, halo_i in enumerate(halos):
        if fn.MODELS[i] == 'REF':
            density_ref = halo_i.density_gas
            
        ax[0].plot(x, halo_i.density_gas * 1e10, lw=3, c=fn.COLORS[fn.MODELS[i]], label=fn.LABELS[fn.MODELS[i]])
        ax[1].plot(x, halo_i.density_gas/density_ref, lw=3, c=fn.COLORS[fn.MODELS[i]])
        
    ax[0].legend(bbox_to_anchor=(0.5, -1.4), loc='lower center', title=fn.LEGEND_TITLE, ncol=2)
    xlim = ax[0].get_xlim()
    ax[1].set_xlim(xlim)
    if is_normalize:
        fig_name = f'normalized_z{z}'
    else:
        fig_name = f'unnormalized_z{z}'

    fg.savefig(fn.HERE_PATH/'Gas_Profiles'/f'{fig_name}.pdf', bbox_inches='tight')
    
    if z == 2 or z == 0:
        fg.savefig(fn.HERE_PATH/'Project_Plots'/f'unnormalized_z{z}.pdf', bbox_inches='tight')
# Out:
# /tmp/ipykernel_254508/4233003976.py:34: RuntimeWarning: invalid value encountered in divide
#   ax[1].plot(x, halo_i.density_gas/density_ref, lw=3, c=fn.COLORS[fn.MODELS[i]])
# /tmp/ipykernel_254508/4233003976.py:34: RuntimeWarning: divide by zero encountered in divide
#   ax[1].plot(x, halo_i.density_gas/density_ref, lw=3, c=fn.COLORS[fn.MODELS[i]])

# %%
a = np.array([1,2,3])
print(a[:,np.newaxis])

# %%
print(halos[0].density_gas[:,np.newaxis])

# %%
print(np.log10(x))
